# %% [markdown]
# Technological Institute of the Philippines | Quezon City - Computer Engineering
# --- | ---
# Course Code: | CPE 019
# Code Title: | Emerging Technologies in CpE 2
# 2nd Semester | AY 2023-2024
# <hr> | <hr>
# <u>**Assignment 7.1** | Classifications and Regression
# **Name** | Buenafe, Dhafny S.
# **Section** | CPE32S3
# **Date Performed**: |April 7, 2024
# **Date Submitted**: |April 11, 2024
# **Instructor**: | Engr. Roman Richard
#
# <hr>

# %% [markdown]
# For classification, do the following:
#   - Create a base model
#   - Evaluate the model with k-fold cross validation
#   - Improve the accuracy of your model by applying additional hidden layers
#
# For regression, do the following:
#   - Create a base model
#   - Improve the model by standardizing the dataset
#   - Show tuning of layers and neurons (see evaluating small and larger networks)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Obesity Classification.csv')

# %% [markdown]
# The data revolves around obesity classification, focusing on how features such as age, gender, height, weight, and BMI influence the classification into categories like underweight, normal weight, overweight, and obesity.  This analysis aims to investigate how these specific features influence the classification process.

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      108 non-null    int64
#  1   Age     108 non-null    int64
#  2   Gender  108 non-null    object
#  3   Height  108 non-null    int64
#  4   Weight  108 non-null    int64
#  5   BMI     108 non-null    float64
#  6   Label   108 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    0
# BMI       0
# Label     0
# dtype: int64

# %%
df["Gender"] = df["Gender"].apply(lambda toLabel: 0 if toLabel == 'Male' else 1)

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25       0     175      80  25.3  Normal Weight
# 1   2   30       1     160      60  22.5  Normal Weight
# 2   3   35       0     180      90  27.3     Overweight
# 3   4   40       1     150      50  20.0    Underweight
# 4   5   45       0     190     100  31.2          Obese

# %%
label_mapping = {'Underweight': 0, 'Normal Weight': 1, 'Overweight': 2, 'Obese': 3}

# %%
df['Encoded_Label'] = df['Label'].map(label_mapping)

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label  Encoded_Label
# 0   1   25       0     175      80  25.3  Normal Weight              1
# 1   2   30       1     160      60  22.5  Normal Weight              1
# 2   3   35       0     180      90  27.3     Overweight              2
# 3   4   40       1     150      50  20.0    Underweight              0
# 4   5   45       0     190     100  31.2          Obese              3

# %%
y = (df["Encoded_Label"])
y
# Out:
# 0      1
# 1      1
# 2      2
# 3      0
# 4      3
#       ..
# 103    0
# 104    0
# 105    0
# 106    0
# 107    0
# Name: Encoded_Label, Length: 108, dtype: int64

# %%
x = df.drop(["ID","Label","Encoded_Label"], axis=1)
x
# Out:
#      Age  Gender  Height  Weight   BMI
# 0     25       0     175      80  25.3
# 1     30       1     160      60  22.5
# 2     35       0     180      90  27.3
# 3     40       1     150      50  20.0
# 4     45       0     190     100  31.2
# ..   ...     ...     ...     ...   ...
# 103   11       0     175      10   3.9
# 104   16       1     160      10   3.9
# 105   21       0     180      15   5.6
# 106   26       1     150      15   5.6
# 107   31       0     190      20   8.3
#
# [108 rows x 5 columns]

# %% [markdown]
# #Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train
# Out:
#     Age  Gender  Height  Weight   BMI
# 14   38       0     190      90  27.3
# 94   17       1     160      15   5.6
# 45   52       1     130      75  25.0
# 76   55       0     210      85  26.1
# 25   93       1     140      40  16.7
# ..  ...     ...     ...     ...   ...
# 46   57       0     210     105  28.9
# 40   27       0     180      75  24.2
# 0    25       0     175      80  25.3
# 90   48       1     130      40  16.7
# 23   83       1     150      50  20.0
#
# [75 rows x 5 columns]

# %%
y_train
# Out:
# 14    2
# 94    0
# 45    2
# 76    2
# 25    0
#      ..
# 46    3
# 40    1
# 0     1
# 90    0
# 23    0
# Name: Encoded_Label, Length: 75, dtype: int64

# %% [markdown]
# #Classification

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
def create_base_model():
    model = Sequential([
        Dense(64, activation='relu', input_shape=(x.shape[1],)),
        Dropout(0.5),  # Adding dropout for regularization
        Dense(32, activation='relu'),
        Dense(4, activation='softmax')  # Output layer with 4 units for classification
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
accuracy_scores = []
for train_index, test_index in kfold.split(x_scaled):
    x_train, x_test = x_scaled[train_index], x_scaled[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create and train model
    model = create_base_model()
    model.fit(x_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Evaluate model
    _, accuracy = model.evaluate(x_test, y_test, verbose=0)
    accuracy_scores.append(accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print("Accuracy: %.2f%%" % (np.mean(accuracy_scores)*100))
# Out:
# Accuracy: 51.77%

# %% [markdown]
# - The conclusion is that the overall accuracy of the model, based on the mean of the accuracy scores, is 51.77%. This suggests that the model's performance in classifying obesity based on the provided features (age, gender, height, weight, and BMI) is moderate, but there is room for improvement. To further improve the accuracy the model should refine or make some adjustments.

# %% [markdown]
# #Regression

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create the base model
model2= Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(4, activation='softmax')
])

# Compile the model
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model2.fit(x_train, y_train, epochs=50, batch_size=18, validation_split=0.3)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.1004 - loss: 1.3999 - val_accuracy: 0.1852 - val_loss: 1.3793
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1859 - loss: 1.3728 - val_accuracy: 0.1852 - val_loss: 1.3535
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3496 - loss: 1.3224 - val_accuracy: 0.1852 - val_loss: 1.3292
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4422 - loss: 1.2667 - val_accuracy: 0.2222 - val_loss: 1.3068
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5200 - loss: 1.2125 - val_accuracy: 0.2593 - val_loss: 1.2870
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4033 - loss: 1.2352 - val_accuracy: 0.2963 - val_loss: 1.2688
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4359 - loss: 1.1954 - val_accuracy: 0.3704 - val_loss: 1.2457
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4285 - loss: 1.1765 - val_accuracy: 0.3704 - val_loss: 1.2252
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4978 - loss: 1.0882 - val_accuracy: 0.3704 - val_loss: 1.2051
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4422 - loss: 1.1082 - val_accuracy: 0.4074 - val_loss: 1.1878
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4704 - loss: 1.0909 - val_accuracy: 0.4444 - val_loss: 1.1724
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5293 - loss: 1.0901 - val_accuracy: 0.4444 - val_loss: 1.1546
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6119 - loss: 1.0004 - val_accuracy: 0.5185 - val_loss: 1.1345
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6252 - loss: 1.0376 - val_accuracy: 0.5185 - val_loss: 1.1174
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6200 - loss: 1.0154 - val_accuracy: 0.5556 - val_loss: 1.0989
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5774 - loss: 0.9826 - val_accuracy: 0.5926 - val_loss: 1.0816
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6496 - loss: 0.9627 - val_accuracy: 0.5926 - val_loss: 1.0614
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6174 - loss: 0.9651 - val_accuracy: 0.5926 - val_loss: 1.0435
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7019 - loss: 0.9094 - val_accuracy: 0.5926 - val_loss: 1.0232
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6474 - loss: 0.9186 - val_accuracy: 0.6296 - val_loss: 1.0030
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6326 - loss: 0.9240 - val_accuracy: 0.6296 - val_loss: 0.9809
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7307 - loss: 0.8741 - val_accuracy: 0.6296 - val_loss: 0.9623
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6796 - loss: 0.8627 - val_accuracy: 0.6296 - val_loss: 0.9456
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7022 - loss: 0.8491 - val_accuracy: 0.6667 - val_loss: 0.9267
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7319 - loss: 0.7924 - val_accuracy: 0.6667 - val_loss: 0.9033
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7515 - loss: 0.7931 - val_accuracy: 0.6667 - val_loss: 0.8823
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6959 - loss: 0.8154 - val_accuracy: 0.6667 - val_loss: 0.8638
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6756 - loss: 0.8522 - val_accuracy: 0.6667 - val_loss: 0.8474
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7570 - loss: 0.7941 - val_accuracy: 0.6667 - val_loss: 0.8310
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7033 - loss: 0.8061 - val_accuracy: 0.6667 - val_loss: 0.8115
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6996 - loss: 0.8109 - val_accuracy: 0.6667 - val_loss: 0.7944
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7367 - loss: 0.7589 - val_accuracy: 0.6667 - val_loss: 0.7777
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6922 - loss: 0.7494 - val_accuracy: 0.6667 - val_loss: 0.7636
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6830 - loss: 0.7700 - val_accuracy: 0.7037 - val_loss: 0.7496
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7915 - loss: 0.6879 - val_accuracy: 0.7037 - val_loss: 0.7358
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6774 - loss: 0.7556 - val_accuracy: 0.7037 - val_loss: 0.7243
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7348 - loss: 0.6972 - val_accuracy: 0.7037 - val_loss: 0.7133
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6848 - loss: 0.7295 - val_accuracy: 0.7037 - val_loss: 0.7018
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7256 - loss: 0.6967 - val_accuracy: 0.7037 - val_loss: 0.6886
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7270 - loss: 0.7147 - val_accuracy: 0.7037 - val_loss: 0.6770
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7881 - loss: 0.6590 - val_accuracy: 0.7037 - val_loss: 0.6674
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7696 - loss: 0.6586 - val_accuracy: 0.7037 - val_loss: 0.6620
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7530 - loss: 0.6767 - val_accuracy: 0.7037 - val_loss: 0.6538
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7530 - loss: 0.6764 - val_accuracy: 0.7037 - val_loss: 0.6471
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7993 - loss: 0.6295 - val_accuracy: 0.7037 - val_loss: 0.6396
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7307 - loss: 0.6467 - val_accuracy: 0.7037 - val_loss: 0.6302
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7615 - loss: 0.6549 - val_accuracy: 0.7037 - val_loss: 0.6248
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7689 - loss: 0.6495 - val_accuracy: 0.7037 - val_loss: 0.6177
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7996 - loss: 0.6304 - val_accuracy: 0.7037 - val_loss: 0.6103
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8052 - loss: 0.6101 - val_accuracy: 0.7037 - val_loss: 0.6047

# %% [markdown]
# - The results show that the model is good at learning from the training data, achieving about 80.52% as highest accuracy. However, it's not as good at handling new, unseen data, as seen in the lower validation accuracy of around 70.37%. This means taht the model is too focused on the specifics of the training data and struggles with new information. The model needs to refine to be able to learn new datas.

# %%
smaller_model = Sequential([
    Dense(32, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(4, activation='softmax')
])

smaller_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
smaller_history = smaller_model.fit(x_train, y_train, epochs=50, batch_size=8, validation_split=0.3)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.1803 - loss: 1.4370 - val_accuracy: 0.0000e+00 - val_loss: 2.3707
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3215 - loss: 1.3077 - val_accuracy: 0.0000e+00 - val_loss: 2.2906
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3327 - loss: 1.3055 - val_accuracy: 0.0000e+00 - val_loss: 2.2105
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3660 - loss: 1.2902 - val_accuracy: 0.0370 - val_loss: 2.1342
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3805 - loss: 1.2419 - val_accuracy: 0.1111 - val_loss: 2.0613
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3533 - loss: 1.2594 - val_accuracy: 0.1111 - val_loss: 1.9921
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4477 - loss: 1.2041 - val_accuracy: 0.1111 - val_loss: 1.9280
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5712 - loss: 1.0657 - val_accuracy: 0.1481 - val_loss: 1.8728
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5431 - loss: 1.1376 - val_accuracy: 0.1852 - val_loss: 1.8205
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5884 - loss: 1.0698 - val_accuracy: 0.1852 - val_loss: 1.7687
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5905 - loss: 1.0552 - val_accuracy: 0.1852 - val_loss: 1.7220
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6599 - loss: 0.9751 - val_accuracy: 0.1852 - val_loss: 1.6724
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6051 - loss: 0.9942 - val_accuracy: 0.2593 - val_loss: 1.6228
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6391 - loss: 0.9859 - val_accuracy: 0.2963 - val_loss: 1.5843
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6999 - loss: 0.9381 - val_accuracy: 0.3704 - val_loss: 1.5382
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7045 - loss: 0.8921 - val_accuracy: 0.3704 - val_loss: 1.4935
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7260 - loss: 0.8835 - val_accuracy: 0.3704 - val_loss: 1.4617
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6315 - loss: 0.9673 - val_accuracy: 0.3704 - val_loss: 1.4217
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6900 - loss: 0.8412 - val_accuracy: 0.3704 - val_loss: 1.3904
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7127 - loss: 0.8518 - val_accuracy: 0.3704 - val_loss: 1.3522
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7677 - loss: 0.7883 - val_accuracy: 0.3704 - val_loss: 1.3265
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6825 - loss: 0.8408 - val_accuracy: 0.4074 - val_loss: 1.2897
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7345 - loss: 0.8112 - val_accuracy: 0.4074 - val_loss: 1.2575
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7645 - loss: 0.7586 - val_accuracy: 0.4074 - val_loss: 1.2316
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6757 - loss: 0.8232 - val_accuracy: 0.4074 - val_loss: 1.2074
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7845 - loss: 0.7057 - val_accuracy: 0.4074 - val_loss: 1.1826
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6706 - loss: 0.8042 - val_accuracy: 0.4074 - val_loss: 1.1581
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7667 - loss: 0.7387 - val_accuracy: 0.4074 - val_loss: 1.1380
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8221 - loss: 0.6569 - val_accuracy: 0.4074 - val_loss: 1.1187
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7501 - loss: 0.6828 - val_accuracy: 0.4074 - val_loss: 1.0905
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7284 - loss: 0.7491 - val_accuracy: 0.4074 - val_loss: 1.0754
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7427 - loss: 0.6778 - val_accuracy: 0.4074 - val_loss: 1.0540
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6453 - loss: 0.7204 - val_accuracy: 0.4074 - val_loss: 1.0326
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6620 - loss: 0.7176 - val_accuracy: 0.4074 - val_loss: 1.0122
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7655 - loss: 0.6654 - val_accuracy: 0.4074 - val_loss: 0.9944
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7191 - loss: 0.6665 - val_accuracy: 0.4444 - val_loss: 0.9797
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7602 - loss: 0.6285 - val_accuracy: 0.4444 - val_loss: 0.9711
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7276 - loss: 0.6625 - val_accuracy: 0.4444 - val_loss: 0.9557
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7245 - loss: 0.6834 - val_accuracy: 0.4815 - val_loss: 0.9357
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7171 - loss: 0.6370 - val_accuracy: 0.4815 - val_loss: 0.9212
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7458 - loss: 0.6120 - val_accuracy: 0.5185 - val_loss: 0.9094
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7407 - loss: 0.6344 - val_accuracy: 0.5185 - val_loss: 0.8951
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7106 - loss: 0.6751 - val_accuracy: 0.5185 - val_loss: 0.8780
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7442 - loss: 0.6146 - val_accuracy: 0.5185 - val_loss: 0.8611
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7788 - loss: 0.5466 - val_accuracy: 0.5185 - val_loss: 0.8529
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8104 - loss: 0.5458 - val_accuracy: 0.5185 - val_loss: 0.8459
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7333 - loss: 0.6049 - val_accuracy: 0.5556 - val_loss: 0.8249
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7425 - loss: 0.6141 - val_accuracy: 0.5556 - val_loss: 0.8096
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7260 - loss: 0.5919 - val_accuracy: 0.5556 - val_loss: 0.7969
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7485 - loss: 0.5843 - val_accuracy: 0.5926 - val_loss: 0.7775

# %%
larger_model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(4, activation='softmax')
])

larger_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
larger_history = larger_model.fit(x_train, y_train, epochs=50, batch_size=8, validation_split=0.3)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2921 - loss: 1.4109 - val_accuracy: 0.6296 - val_loss: 1.2989
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6753 - loss: 1.2185 - val_accuracy: 0.6296 - val_loss: 1.1522
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6866 - loss: 1.0865 - val_accuracy: 0.7037 - val_loss: 1.0199
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6873 - loss: 0.9980 - val_accuracy: 0.7037 - val_loss: 0.9038
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6660 - loss: 0.9105 - val_accuracy: 0.7407 - val_loss: 0.7846
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6547 - loss: 0.8662 - val_accuracy: 0.7407 - val_loss: 0.7047
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7777 - loss: 0.6966 - val_accuracy: 0.7407 - val_loss: 0.6178
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6770 - loss: 0.6820 - val_accuracy: 0.7407 - val_loss: 0.5448
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7261 - loss: 0.6883 - val_accuracy: 0.7407 - val_loss: 0.5040
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8044 - loss: 0.6201 - val_accuracy: 0.7778 - val_loss: 0.4613
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7925 - loss: 0.5421 - val_accuracy: 0.7778 - val_loss: 0.4378
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7861 - loss: 0.4963 - val_accuracy: 0.8148 - val_loss: 0.4045
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.4941 - val_accuracy: 0.8519 - val_loss: 0.3549
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8932 - loss: 0.4527 - val_accuracy: 0.8519 - val_loss: 0.3189
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9104 - loss: 0.3992 - val_accuracy: 0.8519 - val_loss: 0.3057
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8734 - loss: 0.4422 - val_accuracy: 0.8519 - val_loss: 0.2597
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9107 - loss: 0.3743 - val_accuracy: 0.8889 - val_loss: 0.2421
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8911 - loss: 0.3807 - val_accuracy: 0.8889 - val_loss: 0.2331
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9183 - loss: 0.3462 - val_accuracy: 0.8889 - val_loss: 0.2379
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8559 - loss: 0.3698 - val_accuracy: 0.8889 - val_loss: 0.2219
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9320 - loss: 0.3098 - val_accuracy: 0.8889 - val_loss: 0.2089
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9352 - loss: 0.3208 - val_accuracy: 0.8889 - val_loss: 0.2130
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9542 - loss: 0.3243 - val_accuracy: 0.9259 - val_loss: 0.1955
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.2467 - val_accuracy: 0.9259 - val_loss: 0.1844
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9546 - loss: 0.3095 - val_accuracy: 0.9259 - val_loss: 0.1846
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9117 - loss: 0.2790 - val_accuracy: 0.9259 - val_loss: 0.1788
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9443 - loss: 0.2518 - val_accuracy: 0.9259 - val_loss: 0.1815
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9526 - loss: 0.2232 - val_accuracy: 0.9259 - val_loss: 0.1900
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9605 - loss: 0.2380 - val_accuracy: 0.9259 - val_loss: 0.1677
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9603 - loss: 0.2138 - val_accuracy: 0.9259 - val_loss: 0.1509
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1975 - val_accuracy: 0.9259 - val_loss: 0.1495
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9703 - loss: 0.1641 - val_accuracy: 0.9259 - val_loss: 0.1540
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9811 - loss: 0.2159 - val_accuracy: 0.9259 - val_loss: 0.1529
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.1447 - val_accuracy: 0.9259 - val_loss: 0.1559
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9460 - loss: 0.1807 - val_accuracy: 0.9259 - val_loss: 0.1471
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9742 - loss: 0.1689 - val_accuracy: 0.9259 - val_loss: 0.1413
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1498 - val_accuracy: 0.9259 - val_loss: 0.1351
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1488 - val_accuracy: 0.9259 - val_loss: 0.1252
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9892 - loss: 0.1669 - val_accuracy: 0.9259 - val_loss: 0.1385
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9811 - loss: 0.1307 - val_accuracy: 0.9259 - val_loss: 0.1395
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9963 - loss: 0.1265 - val_accuracy: 0.9259 - val_loss: 0.1382
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1462 - val_accuracy: 0.9259 - val_loss: 0.1304
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9943 - loss: 0.1303 - val_accuracy: 0.9259 - val_loss: 0.1358
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1052 - val_accuracy: 0.9259 - val_loss: 0.1363
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1248 - val_accuracy: 0.9259 - val_loss: 0.1388
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1328 - val_accuracy: 0.9259 - val_loss: 0.1303
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.1011 - val_accuracy: 0.9259 - val_loss: 0.1277
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1232 - val_accuracy: 0.9259 - val_loss: 0.1279
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1145 - val_accuracy: 0.9259 - val_loss: 0.1262
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 0.9259 - val_loss: 0.1275

# %% [markdown]
# - The conclusion here is that if we use lots of hidden layers, the data gets clearer, and the model can learn it better. But if we use fewer layers, the model isn't as good and needs improvement.
